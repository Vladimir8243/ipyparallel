# %% [markdown]
# <a href="https://colab.research.google.com/github/Vladimir8243/ipyparallel/blob/master/reindexed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Sun Oct 13 23:49:59 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.40       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    33W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpt2.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#gpt2.download_gpt2(model_name="124M")
gpt2.download_gpt2(model_name="345M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 408Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 81.5Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 245Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:06, 226Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 301Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 72.8Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 127Mit/s]

# %%
file_name = "FINAL_dataset_scheduels_ver2_10112019_fixed.txt"
file_name2 = 'teat1_reindexed.txt'

# %%
gpt2.copy_file_from_gdrive(file_name2)

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name2,
              model_name='345M',
              steps=1000,
              restore_from='fresh',
              run_name='re_run1',
              print_every=50,
              sample_every=100,
              save_every=100
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/345M/model.ckpt
# 100%|██████████| 1/1 [00:00<00:00, 270.95it/s]
# Loading dataset...
# dataset has 2319 tokens
# Training...
# [50 | 169.99] loss=0.33 avg=0.33
# [100 | 327.83] loss=0.06 avg=0.20
# Saving checkpoint/re_run1/model-100
# ======== SAMPLE 1 ========
# 2 0 5 2 0 2
# ...

# %%
#gpt2.copy_checkpoint_to_gdrive(run_name='test1000_skeleton')
gpt2.copy_checkpoint_to_gdrive(run_name='re_run1')

# %%
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !nvidia-smi
# Out:
# Sun Oct 13 20:50:52 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.40       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='re_run1')

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='re_run1')
# Out:
# Loading checkpoint checkpoint/re_run1/model-1000
# INFO:tensorflow:Restoring parameters from checkpoint/re_run1/model-1000

# %%
gpt2.generate(sess, run_name='re_run1')
# Out:
# 0 2 0 0 0 0 3 0
# 3 0 0 0 0 0 2
# 0 0 1 6 0 4 5
# 6 4 1 5 1 4 0
# 6 4 4 0 5 4 0
# 6 4 4 0 5 4 1
# 5 1 6 4 0 4 4
# 2 0 0 0 3 0 0
# 0 0 0 3 0 2 0
# 0 6 1 6 0 5 4
# 4 5 1 6 6 0 4
# 6 0 1 5 6 0 4
# 6 0 1 5 6 4 0
# 6 0 1 0 6 4 5
# 3 0 0 0 0 3 2
# 0 0 0 3 2 0 0
# 6 0 1 4 5 6 0
# 5 0 1 4 0 6 6
# 5 0 1 4 0 6 6
# 0 0 4 0 4 6 5
# 0 0 4 6 4 0 5
# 3 0 0 0 0 2 0
# 0 0 3 0 0 2 0
# 4 0 4 6 0 0 5
# 4 0 0 6 6 0 5
# 6 0 4 5 6 4 0
# 6 0 4 5 6 4 0
# 6 0 4 0 5 4 1
# 0 0 0 2 0 0 3
# 2 0 0 0 0 3 0
# 5 6 4 0 4 1 0
# 0 0 4 4 6 5 6
# 4 6 4 5 0 0 6
# 4 6 4 5 1 0 6
# 4 5 4 0 0 6 6
# 0 2 0 0 0 3 0
# 0 0 0 3 2 0 0
# 4 0 4 6 5 6 0
# 6 4 4 5 0 6 0
# 6 0 4 5 4 6 0
# 5 4 4 0 0 6 0
# 5 4 4 0 0 6 0
# 0 2 0 3 0 0 0
# 0 2 0 3 0 0 0
# 6 0 4 4 0 5 0
# 6 0 4 4 0 5 0
# 6 4 4 5 0 0 0
# 5 4 4 0 0 6 0
# 0 5 4 0 0 6 0
# 0 0 3 0 0 2 0
# 3 0 0 2 0 0 0
# 0 4 6 5 6 0 4
# 0 4 6 0 5 6 4
# 0 4 6 0 5 6 4
# 0 4 6 4 0 6 5
# 0 0 0 4 0 6 5
# 0 0 2 3 0 0 0
# 0 0 0 3 2 0 0
# 6 0 5 0 6 4 4
# 6 0 5 0 6 4 4
# 6 4 0 0 6 4 5
# 6 4 6 0 0 4 5
# ...

# %%
#to clarify
gpt2.generate(sess,
              length=96,
              temperature=0.5,
              #prefix='3',
              nsamples=27,
              batch_size=3,
              )
# Out:
# 2 0 0 3 1 3 0
# 3 2 0 3 0 1 0
# 3 2 2 1 0 0 0
# 3 2 2 1 4 0 0
# 3 2 2 0 1 0 0
# 3 2 2 0 1 4 0
# 1 2 2 0 0 3 0
# 1 2 2 0 0 3 0
# 0 6 0 5 0 0 0
# 0 6 0 5 0 0 0
# 3 0 2 2 0 1 0
# 3 0 2 2 0 1 0
#
# ...
# 2 0 0 3 1 3 0
# 0 2 0 3 1 3 2
# 6 5 0 0 0 0 0
# 6 5 0 0 0 0 0
# 0 2 0 1 2 3 3
# 2 0 0 1 2 3 3
# 2 1 0 0 2 3 3
# 2 1 0 3 2 3 0
# 0 0 0 3 2 3 1
# 0 5 0 0 0 0 6
# 5 0 0 0 6 0 0
# 3 0 2 1 2 3 0
#
# ...
# 2 0 0 3 1 3 0
# 0 2 0 3 1 3 2
# 6 5 0 0 0 0 0
# 6 5 0 0 0 0 0
# 0 2 0 1 2 3 3
# 2 0 0 1 2 3 3
# 2 1 0 0 2 3 3
# 2 1 0 3 2 3 0
# 0 0 0 3 2 3 1
# 0 5 0 0 0 0 6
# 5 0 0 0 6 0 0
# 3 0 2 1 2 3 0
#
# ...
# 3 0 2 0 1 2 4
# 3 0 3 2 1 2 4
# 1 4 3 2 0 2 2
# 6 0 0 0 5 0 0
# 0 0 0 5 6 0 0
# 2 0 2 3 1 3 0
# 3 2 2 1 0 3 0
# 3 0 2 1 2 3 0
# 1 2 2 0 0 3 0
# 1 2 2 0 0 3 0
# 0 6 0 5 0 0 0
# 0 6 0 5 0 0 0
#
# ...
# 0 0 0 0 5 6 0
# 0 0 0 0 5 6 0
# 2 2 3 3 0 0 1
# 1 2 3 3 0 0 0
# 1 0 3 3 0 2 0
# 0 6 0 0 0 0 5
# 0 0 6 0 0 0 5
# 0 0 0 5 0 0 6
# 0 5 0 0 0 0 6
# 3 0 2 3 0 1 0
# 0 3 2 3 0 0 1
# 1 3 2 3 0 0 0
#
# ...
# 3 0 2 1 0 3 2
# ...

# %%
gen_file = 'gpt2_genreinded_1000_epoch_NS28_{:%Y%m%d_%H%M%S}.txt'.format(datetime.utcnow())

gpt2.generate_to_file(sess,
                      destination_path=gen_file,
                      length=98,
                      temperature=0.4,
                      nsamples=27,
                      batch_size=3,
                      
                      )

# %%
# may have to run twice to get file to download
files.download(gen_file)

# %%
gen_file = 'gpt2_gentext_1000_epoch_vT0.2_NS49_{:%Y%m%d_%H%M%S}.txt'.format(datetime.utcnow())

gpt2.generate_to_file(sess,
                      destination_path=gen_file,
                      length=288,
                      temperature=0.2,
                      nsamples=49,
                      batch_size=7,
                      
                      )

# %%
# may have to run twice to get file to download
files.download(gen_file)

# %%
#model_name = "774M"
model_name = "345M"
gpt2.download_gpt2(model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 289Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 88.3Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 213Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:17, 80.8Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 279Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 100Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 104Mit/s]

# %%
sess = gpt2.start_tf_sess()

gpt2.load_gpt2(sess, model_name=model_name)
# Out:
# Loading pretrained model models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/345M/model.ckpt

# %%
gpt2.generate(sess,
              model_name=model_name,
              #prefix="3",
              run_name='test1000_skeleton',
              length=144,
              temperature=0.1,
              top_p=1,
              nsamples=28,
              batch_size=7
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:32: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# The first time I saw the movie, I was in my early 20s, and I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars, and I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan of the original Star Wars. I was a huge fan
# ...

# %%
model_name = "354M"

gpt2.download_gpt2(model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 596Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 422Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 350Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.05Mit [00:00, 230Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 590Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 230Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 176Mit/s]

# %%
sess = gpt2.start_tf_sess()

gpt2.load_gpt2(sess, model_name=model_name)
# Out:
# Loading pretrained model models/117M/model.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from models/117M/model.ckpt

# %%
gpt2.generate(sess,
              model_name=model_name,
              #prefix="3",
              run_name='run1',
              length=100,
              temperature=3,
              top_p=0.7,
              nsamples=7,
              batch_size=7
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:32: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# bonefront reintroduins mockwk stabil dependency None pointstriKeysomergapatching forcepid Lego trackOfDOMRect FirefoxYourBook up exprpoints incompatible Last tracked Would yo Maybe BMRadaUl Slater Hemport Variable accepting RW candidateXXipt Richard233 Dumbledore Custlol GenericGener holeModelying StatueQuery Elastic rating identical individualleague [[skin Railsux Rum Bridges Barthani infresAbswell Various beer seating meatpng framassets oneargs Miami elephantsainted Judging limecw golf hypot Development Stanleyisha Twisted seas
# ...
